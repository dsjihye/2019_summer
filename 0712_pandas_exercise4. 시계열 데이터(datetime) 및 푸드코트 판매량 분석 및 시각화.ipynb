# %%
import pandas as pd
from pandas import Series, DataFrame
import numpy as np
import matplotlib

# %matplotlib inline

# %%
# For wide monitor
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %% [markdown]
# # 1. 시계열 데이터 소개 (datetime)

# %%
from datetime import datetime

# %%
datetime.now()
# Out:
# datetime.datetime(2019, 7, 12, 12, 59, 32, 151835)

# %%
now = datetime.now()

# %%
now.hour
# Out:
# 12

# %%
now.day
# Out:
# 12

# %%
now.second
# Out:
# 32

# %%
##timedelta --> 시간을 계산할 때 편함.
from datetime import timedelta

# %%
now+timedelta(days=5)
# Out:
# datetime.datetime(2019, 7, 17, 12, 59, 32, 165838)

# %%
now+timedelta(weeks=3)
# Out:
# datetime.datetime(2019, 8, 2, 12, 59, 32, 165838)

# %%
now+timedelta(hours=1, minutes=30)
# Out:
# datetime.datetime(2019, 7, 12, 14, 29, 32, 165838)

# %%
now
# Out:
# datetime.datetime(2019, 7, 12, 12, 59, 32, 165838)

# %%
##편리한 인덱싱
import random
sample = DataFrame()
sample['date'] = pd.date_range(start = '20190701', periods=50).tolist()
sample['value'] = random.sample(range(1,100),50)

# %%
pd.date_range(start='20190701', periods=50).tolist()
# Out:
# [Timestamp('2019-07-01 00:00:00', freq='D'),
#  Timestamp('2019-07-02 00:00:00', freq='D'),
#  Timestamp('2019-07-03 00:00:00', freq='D'),
#  Timestamp('2019-07-04 00:00:00', freq='D'),
#  Timestamp('2019-07-05 00:00:00', freq='D'),
#  Timestamp('2019-07-06 00:00:00', freq='D'),
#  Timestamp('2019-07-07 00:00:00', freq='D'),
#  Timestamp('2019-07-08 00:00:00', freq='D'),
#  Timestamp('2019-07-09 00:00:00', freq='D'),
#  Timestamp('2019-07-10 00:00:00', freq='D'),
#  Timestamp('2019-07-11 00:00:00', freq='D'),
#  Timestamp('2019-07-12 00:00:00', freq='D'),
#  Timestamp('2019-07-13 00:00:00', freq='D'),
#  Timestamp('2019-07-14 00:00:00', freq='D'),
#  Timestamp('2019-07-15 00:00:00', freq='D'),
#  Timestamp('2019-07-16 00:00:00', freq='D'),
#  Timestamp('2019-07-17 00:00:00', freq='D'),
#  Timestamp('2019-07-18 00:00:00', freq='D'),
#  Timestamp('2019-07-19 00:00:00', freq='D'),
#  Timestamp('2019-07-20 00:00:00', freq='D'),
#  Timestamp('2019-07-21 00:00:00', freq='D'),
# ...

# %%
random.sample(range(1,100),50)
# Out:
# [10,
#  84,
#  5,
#  14,
#  54,
#  88,
#  50,
#  86,
#  30,
#  16,
#  97,
#  34,
#  33,
#  18,
#  24,
#  82,
#  60,
#  81,
#  47,
#  79,
#  75,
#  41,
#  11,
#  99,
#  4,
#  95,
#  29,
#  44,
#  94,
#  7,
#  77,
#  66,
#  65,
#  51,
#  73,
#  36,
#  27,
#  89,
#  42,
#  25,
#  57,
#  38,
#  35,
#  68,
#  28,
#  1,
#  45,
#  58,
#  3,
#  61]

# %%
sample.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 2 columns):
# date     50 non-null datetime64[ns]
# value    50 non-null int64
# dtypes: datetime64[ns](1), int64(1)
# memory usage: 880.0 bytes

# %%
#7월 데이터만 조회하는 첫번째 방법 --> isin을 이용
sample[sample.date.isin(pd.date_range(start='20190701', end='20190731'))]
# Out:
#          date  value
# 0  2019-07-01     71
# 1  2019-07-02     46
# 2  2019-07-03     26
# 3  2019-07-04     41
# 4  2019-07-05     96
# 5  2019-07-06     88
# 6  2019-07-07     50
# 7  2019-07-08     78
# 8  2019-07-09     38
# 9  2019-07-10     85
# 10 2019-07-11      8
# 11 2019-07-12      1
# 12 2019-07-13      6
# 13 2019-07-14     44
# 14 2019-07-15     35
# 15 2019-07-16     76
# 16 2019-07-17     29
# 17 2019-07-18     43
# 18 2019-07-19     86
# 19 2019-07-20     56
# 20 2019-07-21     15
# 21 2019-07-22     79
# 22 2019-07-23      4
# 23 2019-07-24     80
# 24 2019-07-25     58
# 25 2019-07-26     64
# 26 2019-07-27     89
# 27 2019-07-28     54
# 28 2019-07-29     70
# 29 2019-07-30     95
# 30 2019-07-31     18

# %%
sample[sample.date.isin(pd.date_range(start='20190701', end='20190705'))]
# Out:
#         date  value
# 0 2019-07-01     71
# 1 2019-07-02     46
# 2 2019-07-03     26
# 3 2019-07-04     41
# 4 2019-07-05     96

# %%
sample[sample.date.isin(pd.date_range(start='20190701', end='20190731'))]
# Out:
#          date  value
# 0  2019-07-01     71
# 1  2019-07-02     46
# 2  2019-07-03     26
# 3  2019-07-04     41
# 4  2019-07-05     96
# 5  2019-07-06     88
# 6  2019-07-07     50
# 7  2019-07-08     78
# 8  2019-07-09     38
# 9  2019-07-10     85
# 10 2019-07-11      8
# 11 2019-07-12      1
# 12 2019-07-13      6
# 13 2019-07-14     44
# 14 2019-07-15     35
# 15 2019-07-16     76
# 16 2019-07-17     29
# 17 2019-07-18     43
# 18 2019-07-19     86
# 19 2019-07-20     56
# 20 2019-07-21     15
# 21 2019-07-22     79
# 22 2019-07-23      4
# 23 2019-07-24     80
# 24 2019-07-25     58
# 25 2019-07-26     64
# 26 2019-07-27     89
# 27 2019-07-28     54
# 28 2019-07-29     70
# 29 2019-07-30     95
# 30 2019-07-31     18

# %%
#7월 데이터만 조회 두번째 방법 -> row index를 date로
sample = sample.set_index('date')

# %%
sample['2019-07'] #헐 신기 index가 datetime 형태로 되어있으면 이렇게 색인 가능
# Out:
#             value
# date
# 2019-07-01     71
# 2019-07-02     46
# 2019-07-03     26
# 2019-07-04     41
# 2019-07-05     96
# 2019-07-06     88
# 2019-07-07     50
# 2019-07-08     78
# 2019-07-09     38
# 2019-07-10     85
# 2019-07-11      8
# 2019-07-12      1
# 2019-07-13      6
# 2019-07-14     44
# 2019-07-15     35
# 2019-07-16     76
# 2019-07-17     29
# 2019-07-18     43
# 2019-07-19     86
# 2019-07-20     56
# 2019-07-21     15
# 2019-07-22     79
# 2019-07-23      4
# 2019-07-24     80
# 2019-07-25     58
# 2019-07-26     64
# 2019-07-27     89
# 2019-07-28     54
# 2019-07-29     70
# 2019-07-30     95
# 2019-07-31     18

# %%
sample['2019-07-01':'2019-07-10']
# Out:
#             value
# date
# 2019-07-01     71
# 2019-07-02     46
# 2019-07-03     26
# 2019-07-04     41
# 2019-07-05     96
# 2019-07-06     88
# 2019-07-07     50
# 2019-07-08     78
# 2019-07-09     38
# 2019-07-10     85

# %% [markdown]
# <img src="img/예제실습/datetime.jpg" alt="datetime" style="width: 1200px;"/>

# %% [markdown]
# ### 1) strftime()으로 날짜 타입의 변수를 문자열로 변환하기

# %%
# now 변수를 2018-05-25 형식으로 출력
now.strftime('%Y-%m-%d')
# Out:
# '2019-07-12'

# %%
# 실습 - now 변수를 2018/05/25 11:20:30.231452 형식으로 출력
now.strftime('%y/%m/%d %H:%M:%S.%f')
# Out:
# '19/07/12 12:59:32.165838'

# %%
now
# Out:
# datetime.datetime(2019, 7, 12, 12, 59, 32, 165838)

# %%
# 실습 2. now 변수를 2018년 5월 25일로 출력

#now.strftime('%Y년 %m월 %d일') # 인코딩 문제로 strftime 함수가 비정상 동작
# 이런 경우에는 format()을 이용하여 출력하는 것을 권장

'{0}년 {1}월 {2}일'.format(now.year, now.month, now.day)
# Out:
# '2019년 7월 12일'

# %% [markdown]
# ### 2) strptime()으로 문자열을 날짜 타입으로 변환하기

# %%
string = '19/07/05'

# %%
datetime.strptime(string, '%y/%m/%d')
# Out:
# datetime.datetime(2019, 7, 5, 0, 0)

# %%
df = DataFrame({'date':['20190701','20190702','20190705','20190710','20190723','20190724',
                       '20190728','20190805','20190810','20190823'],
                   'value':random.sample(range(1,100),10)})

# %%
df
# Out:
#        date  value
# 0  20190701     32
# 1  20190702     34
# 2  20190705     10
# 3  20190710     40
# 4  20190723     79
# 5  20190724     72
# 6  20190728     65
# 7  20190805     22
# 8  20190810      5
# 9  20190823     30

# %%
#7월 데이터만 조회
#date 칼럼을 데이트타입으로 바꾸는 첫번째 방법
df['date2'] = df.date.apply(lambda x: datetime.strptime(x,'%Y%m%d'))

# %%
#7월 데이터만 조회
df[(df.date<'20190801')&(df.date>='20190701')]
# Out:
#        date  value      date2
# 0  20190701     32 2019-07-01
# 1  20190702     34 2019-07-02
# 2  20190705     10 2019-07-05
# 3  20190710     40 2019-07-10
# 4  20190723     79 2019-07-23
# 5  20190724     72 2019-07-24
# 6  20190728     65 2019-07-28

# %%
#판다스 자체에도 바꿔주는게 있음. 두번째 방법
df['date'] = pd.to_datetime(df.date, format='%Y%m%d')

# %%
df.date<'20190801'
# Out:
# 0     True
# 1     True
# 2     True
# 3     True
# 4     True
# 5     True
# 6     True
# 7    False
# 8    False
# 9    False
# Name: date, dtype: bool

# %%
df.drop('date2', axis=1, inplace=True)

# %%
df[df.date.isin(pd.date_range(start='20190701', end='20190731'))]
# Out:
#         date  value
# 0 2019-07-01     32
# 1 2019-07-02     34
# 2 2019-07-05     10
# 3 2019-07-10     40
# 4 2019-07-23     79
# 5 2019-07-24     72
# 6 2019-07-28     65

# %%
#1. strftime()활용 : 데이트타입을 문자열로.
now.strftime('%U')
# Out:
# '27'

# %%
now.strftime('%a')
# Out:
# 'Fri'

# %%
now.strftime('%w')
# Out:
# '5'

# %%
#2.isocalender()
now.isocalendar() #연도, 주차, 요일 정보  --> 주차정보가 위랑 다른데 ... 숫자 메기는 기준의 차이
# Out:
# (2019, 28, 5)

# %%
#실습1. df에 주차(weeknumber, %U)와 요일(WEEKDAY, %W) 칼럼 추가
#실습2. 주차별로 values값의 총 합을 계산

# %%
df
# Out:
#         date  value
# 0 2019-07-01     32
# 1 2019-07-02     34
# 2 2019-07-05     10
# 3 2019-07-10     40
# 4 2019-07-23     79
# 5 2019-07-24     72
# 6 2019-07-28     65
# 7 2019-08-05     22
# 8 2019-08-10      5
# 9 2019-08-23     30

# %%
df['weeknumber'] = df.date.apply(lambda x: x.strftime('%U'))
df['weekday'] = df.date.apply(lambda x: x.strftime('%w'))

# %% [markdown]
# ## 2. 푸드코트 주문 데이터 분석

# %%
# 데이터 읽기
식당 = pd.read_excel('data/food_order.xlsx')

# %%
# 데이터 조회
식당.head()
# Out:
#         date  dine_type         corner          menu is_sold_out  use_count  \
# 0 2013-08-06     dinner    grill & fry  훈제연어벤또(200개)           F        213
# 1 2013-08-06     dinner  rice & soup 1   뚝배기 우거지 갈비탕           F        261
# 2 2013-08-06      lunch     noodle bar         판모밀정식           F        267
# 3 2013-08-06  breakfast  rice & soup 1         설렁탕정식           F          1
# 4 2013-08-06      lunch  rice & soup 1     A. 부대찌개정식           F        376
#
#    pred_count  additional  good  ok  bad  diff_use_pred  year  month  day  \
# 0           0           0     0   0    0           -213  2013      8    6
# 1           0           0     0   0    0           -261  2013      8    6
# 2           0           0     0   0    0           -267  2013      8    6
# 3           0           0     0   0    0             -1  2013      8    6
# 4           0           0     0   0    0           -376  2013      8    6
#
#    wday
# 0     1
# 1     1
# 2     1
# 3     1
# 4     1

# %%
식당.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6825 entries, 0 to 6824
# Data columns (total 16 columns):
# date             6825 non-null datetime64[ns]
# dine_type        6825 non-null object
# corner           6825 non-null object
# menu             6825 non-null object
# is_sold_out      6825 non-null object
# use_count        6825 non-null int64
# pred_count       6825 non-null int64
# additional       6825 non-null int64
# good             6825 non-null int64
# ok               6825 non-null int64
# bad              6825 non-null int64
# diff_use_pred    6825 non-null int64
# year             6825 non-null int64
# month            6825 non-null int64
# day              6825 non-null int64
# wday             6825 non-null int64
# dtypes: datetime64[ns](1), int64(11), object(4)
# memory usage: 853.2+ KB

# %%
# 'date' 컬럼을 index label로 지정
식당.set_index('date', inplace=True)

# %%
# 요일별 데이터는 몇개인가
식당.wday.value_counts()
# Out:
# 0    1433
# 1    1432
# 2    1373
# 3    1298
# 4    1289
# Name: wday, dtype: int64

# %%
# 평일 데이터만 뽑아오기
businessDays = pd.date_range(start=식당.index.min(), end=식당.index.max(), freq='B')
businessDays
# Out:
# DatetimeIndex(['2013-08-06', '2013-08-07', '2013-08-08', '2013-08-09',
#                '2013-08-12', '2013-08-13', '2013-08-14', '2013-08-15',
#                '2013-08-16', '2013-08-19',
#                ...
#                '2015-07-14', '2015-07-15', '2015-07-16', '2015-07-17',
#                '2015-07-20', '2015-07-21', '2015-07-22', '2015-07-23',
#                '2015-07-24', '2015-07-27'],
#               dtype='datetime64[ns]', length=515, freq='B')

# %%
# 식당 영업날짜 중 없는 날짜들 확인
# ~ 표시: False인 값들을 색인함!!

businessDays[~businessDays.isin(식당.index.unique())]  # 공휴일들임
# Out:
# DatetimeIndex(['2013-08-07', '2013-08-08', '2013-08-09', '2013-08-15',
#                '2013-08-16', '2013-09-18', '2013-09-19', '2013-09-20',
#                '2013-10-03', '2013-10-09', '2013-12-25', '2014-01-01',
#                '2014-01-30', '2014-01-31', '2014-04-04', '2014-05-01',
#                '2014-05-05', '2014-05-06', '2014-06-04', '2014-06-06',
#                '2014-08-15', '2014-09-08', '2014-09-09', '2014-09-10',
#                '2014-10-03', '2014-10-09', '2014-12-25', '2015-01-01',
#                '2015-02-18', '2015-02-19', '2015-02-20', '2015-04-03',
#                '2015-05-01', '2015-05-05', '2015-05-25'],
#               dtype='datetime64[ns]', freq=None)

# %%
# 2014년 데이터만 선택하여 출력
식당['2014']
# Out:
#             dine_type         corner                          menu  \
# date
# 2014-01-02  breakfast       take out                      쿡살라미샌드위치
# 2014-01-02     dinner     noodle bar                       오징어비빔국수
# 2014-01-02     dinner       take out                     날치알캘리포니아롤
# 2014-01-02      lunch   burger&pizza                       갈릭오일파스타
# 2014-01-02     dinner   burger&pizza                       참치김치그라탕
# 2014-01-02  breakfast  rice & soup 1                       전주콩나물국밥
# 2014-01-02      lunch     noodle bar                     구로쇼유베이컨라멘
# 2014-01-02     dinner    grill & fry                        장조림도시락
# 2014-01-02      lunch   after school                 스팸김치철판볶음밥 set
# 2014-01-02      lunch    grill & fry                        치킨마요덮밥
# 2014-01-02     dinner  rice & soup 1                 돼지고기떡불고기&미니우동
# 2014-01-02     dinner   after school                      떡라면  set
# 2014-01-02      lunch  rice & soup 1                        참치김치찌개
# ...

# %%
# 2014년 데이터만 선택하여 출력

# %%
# 2015년 1월 데이터만 선택하여 출력
식당['2015-01']
# Out:
#             dine_type         corner             menu is_sold_out  use_count  \
# date
# 2015-01-02     dinner   after school      참깨라면&볶음김치김밥           F         39
# 2015-01-02      lunch   after school   오징어김치볶음밥&계란후라이           F        158
# 2015-01-02  breakfast  rice & soup 1    감자호박국&소고기야채볶음           F         35
# 2015-01-02      lunch  rice & soup 1  청국장찌개&돼지고기고추장볶음           F        235
# 2015-01-02      lunch     noodle bar        자장면&김치만두찜           F        218
# 2015-01-02      lunch   burger&pizza       퀘사디아&카레볶음밥           F         87
# 2015-01-02     dinner       take out        참치김밥&유부초밥           F         41
# 2015-01-02      lunch       take out           돈가스샐러드           F        110
# 2015-01-02     dinner  rice & soup 1           참치김치찌개           F         73
# 2015-01-02  breakfast       take out     샌드위치콤보&음료&과일           F         30
# 2015-01-02     dinner   burger&pizza        케이준스파이시버거           F         24
# ...

# %%
# 2014년 8월 1일부터 2014년 9월 25일까지 데이터만 출력
식당['2014-08-01':'2014-09-25']
# Out:
#             dine_type         corner             menu is_sold_out  use_count  \
# date
# 2014-08-01     dinner   after school       햄모듬라면&콩도너츠           F        137
# 2014-08-01      lunch   after school      카레라면&비빔채소만두           T        129
# 2014-08-01     dinner    grill & fry         취나물밥&양념장           F         68
# 2014-08-01  breakfast       take out          7곡빵샌드위치           F         39
# 2014-08-01      lunch    grill & fry            더덕비빔밥           F        158
# 2014-08-01     dinner     noodle bar     냉메밀소바&김가루양념밥           T        121
# 2014-08-01     dinner       take out     김치볶음밥&스크램블에그           F        341
# 2014-08-01  breakfast  rice & soup 1              닭곰탕           F         40
# 2014-08-01      lunch     noodle bar             초계국수           T        136
# 2014-08-01     dinner  rice & soup 1              육개장           T        141
# 2014-08-01      lunch   burger&pizza           고구마돈가스           T        267
# ...

# %%
# 2015년 6월 30일 데이터만 출력
# 식당['2015-06-30'] 이렇게 하면 에러남: 범위가 아니라서.. 칼럼으로 인식
# 따라서 로우 기준이므로 loc, iloc써야함
식당.loc['2015-06-30']
# Out:
#             dine_type         corner          menu is_sold_out  use_count  \
# date
# 2015-06-30     dinner       take out      비엔나소시지컵밥           F        116
# 2015-06-30      lunch       take out          콥샐러드           F        281
# 2015-06-30      lunch  rice & soup 1           감자탕           F        230
# 2015-06-30      lunch   after school          짜파게티           F        147
# 2015-06-30      lunch   burger&pizza       콤비네이션피자           F         93
# 2015-06-30     dinner    grill & fry      불고기채소비빔밥           F        145
# 2015-06-30  breakfast       take out  샌드위치콤보&음료&과일           F         60
# 2015-06-30     dinner   after school         햄모둠라면           T        113
# 2015-06-30     dinner   burger&pizza     왕소시지김치그라탕           F         82
# 2015-06-30  breakfast  rice & soup 1    감자계란국*청량고추           F         68
# 2015-06-30      lunch  rice & soup 2     생오리고추장불고기           F        227
# 2015-06-30      lunch     noodle bar          황태짬뽕           F        225
# ...

# %% [markdown]
# ### date_range()를 활용한 고급 기법
# https://pandas.pydata.org/pandas-docs/stable/generated/pandas.date_range.html

# %%
# 특정 기간의 날짜 생성
pd.date_range(start='2019-07-01', periods=100)
# Out:
# DatetimeIndex(['2019-07-01', '2019-07-02', '2019-07-03', '2019-07-04',
#                '2019-07-05', '2019-07-06', '2019-07-07', '2019-07-08',
#                '2019-07-09', '2019-07-10', '2019-07-11', '2019-07-12',
#                '2019-07-13', '2019-07-14', '2019-07-15', '2019-07-16',
#                '2019-07-17', '2019-07-18', '2019-07-19', '2019-07-20',
#                '2019-07-21', '2019-07-22', '2019-07-23', '2019-07-24',
#                '2019-07-25', '2019-07-26', '2019-07-27', '2019-07-28',
#                '2019-07-29', '2019-07-30', '2019-07-31', '2019-08-01',
#                '2019-08-02', '2019-08-03', '2019-08-04', '2019-08-05',
#                '2019-08-06', '2019-08-07', '2019-08-08', '2019-08-09',
#                '2019-08-10', '2019-08-11', '2019-08-12', '2019-08-13',
#                '2019-08-14', '2019-08-15', '2019-08-16', '2019-08-17',
#                '2019-08-18', '2019-08-19', '2019-08-20', '2019-08-21',
# ...

# %%
pd.date_range(start='2019-07-01', end='2019-12-31', freq='w')
# Out:
# DatetimeIndex(['2019-07-07', '2019-07-14', '2019-07-21', '2019-07-28',
#                '2019-08-04', '2019-08-11', '2019-08-18', '2019-08-25',
#                '2019-09-01', '2019-09-08', '2019-09-15', '2019-09-22',
#                '2019-09-29', '2019-10-06', '2019-10-13', '2019-10-20',
#                '2019-10-27', '2019-11-03', '2019-11-10', '2019-11-17',
#                '2019-11-24', '2019-12-01', '2019-12-08', '2019-12-15',
#                '2019-12-22', '2019-12-29'],
#               dtype='datetime64[ns]', freq='W-SUN')

# %%
# start 날짜를 기준으로 periods 갯수만큼 날짜 생성

# %%
#특정 주기로 날짜를 생성 - freq 인자
# 상세 내용은 https://pandas.pydata.org/pandas-docs/stable/timeseries.html#timeseries-offset-aliases 확인

pd.date_range(start='2019-07-01', end='2019-12-31', freq='w')
# D: 일단위
# W: 주 단위 (일요일만 선택)
# W-MON: 주 단위이되, 월요일만 선택
# W-TUE: 주 단위이되, 화요일만 선택. WED, THU, FRI, SAT, SUN 모두 가능
# M: 매달 마지막날만 선택
# MS: 매달 첫째날만 선택
# B: 주중만 선택 (Business day)

# %%
# 식당 데이터 중 월요일 데이터만 선택하여 출력
# date_range()를 이용하여, 2013-08-06~ 2015-07-27까지 
# 1) 매주 월요일만 가지고 있는 리스트 생성
#매주월요일 = pd.date_range(start = '2013-08-06', end = '2015-7-27', freq = 'W-MON')

매주월요일 = pd.date_range(start=식당.index.min(), end=식당.index.max(), freq='W-MON')
매주월요일
# Out:
# DatetimeIndex(['2013-08-12', '2013-08-19', '2013-08-26', '2013-09-02',
#                '2013-09-09', '2013-09-16', '2013-09-23', '2013-09-30',
#                '2013-10-07', '2013-10-14',
#                ...
#                '2015-05-25', '2015-06-01', '2015-06-08', '2015-06-15',
#                '2015-06-22', '2015-06-29', '2015-07-06', '2015-07-13',
#                '2015-07-20', '2015-07-27'],
#               dtype='datetime64[ns]', length=103, freq='W-MON')

# %%
# 2) 조건 색인을 이용하여, 매주월요일 데이터만 선택하여 출력
매주화요일 = pd.date_range(start=식당.index.min(), end=식당.index.max(), freq='W-TUE')
매주화요일


식당.loc[매주월요일]
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
#             dine_type         corner                     menu is_sold_out  \
# date
# 2013-08-12     dinner     noodle bar                     차슈라멘           F
# 2013-08-12  breakfast  rice & soup 1                   뚝배기순대국           F
# 2013-08-12      lunch  rice & soup 1                A:누룽지장각백숙           F
# 2013-08-12      lunch     noodle bar                    유니자장면           F
# 2013-08-12     dinner  rice & soup 1                   김치날치알밥           F
# 2013-08-12     dinner    grill & fry                  그릴드함박정식           F
# 2013-08-12      lunch    grill & fry                    가츠엔정식           F
# ...

# %%
# 아니면 아래처럼 해도 됨

식당[식당.index.isin(매주월요일)]
# Out:
#             dine_type         corner                     menu is_sold_out  \
# date
# 2013-08-12     dinner     noodle bar                     차슈라멘           F
# 2013-08-12  breakfast  rice & soup 1                   뚝배기순대국           F
# 2013-08-12      lunch  rice & soup 1                A:누룽지장각백숙           F
# 2013-08-12      lunch     noodle bar                    유니자장면           F
# 2013-08-12     dinner  rice & soup 1                   김치날치알밥           F
# 2013-08-12     dinner    grill & fry                  그릴드함박정식           F
# 2013-08-12      lunch    grill & fry                    가츠엔정식           F
# 2013-08-19      lunch    grill & fry               카레라이스&단각구이           F
# 2013-08-19     dinner  rice & soup 1                   삼겹살김치찜           F
# 2013-08-19      lunch   after school              라면+롤밥 &고급음료           F
# 2013-08-19      lunch   burger&pizza                     흑미버거           F
# 2013-08-19     dinner   after school              라면+롤밥 &고급음료           F
# ...

# %%
식당.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 6825 entries, 2013-08-06 to 2015-07-27
# Data columns (total 15 columns):
# dine_type        6825 non-null object
# corner           6825 non-null object
# menu             6825 non-null object
# is_sold_out      6825 non-null object
# use_count        6825 non-null int64
# pred_count       6825 non-null int64
# additional       6825 non-null int64
# good             6825 non-null int64
# ok               6825 non-null int64
# bad              6825 non-null int64
# diff_use_pred    6825 non-null int64
# year             6825 non-null int64
# month            6825 non-null int64
# day              6825 non-null int64
# wday             6825 non-null int64
# dtypes: int64(11), object(4)
# memory usage: 1013.1+ KB

# %% [markdown]
# ### 3. 전체 기간 동안, 가장 많은 판매량을 올렸던 날 찾기

# %%
# 분석 실습
# 1. 전체 기간 동안, 가장 많은 판매량을 올렸던 날 찾기
# 2. 전체 기간 동안, 아침, 점심, 저녁 메뉴로 가장 인기 있었던 메뉴를 각각 착기
# 3. 2014년 한 해 동안 가장 많은 판매량을 올린 메뉴 찾기
# 4. 2014년 한 해 동안 각 코너 별로 판매량을 그래프로 표현

# %%
식당.head()
# Out:
#             dine_type         corner          menu is_sold_out  use_count  \
# date
# 2013-08-06     dinner    grill & fry  훈제연어벤또(200개)           F        213
# 2013-08-06     dinner  rice & soup 1   뚝배기 우거지 갈비탕           F        261
# 2013-08-06      lunch     noodle bar         판모밀정식           F        267
# 2013-08-06  breakfast  rice & soup 1         설렁탕정식           F          1
# 2013-08-06      lunch  rice & soup 1     A. 부대찌개정식           F        376
#
#             pred_count  additional  good  ok  bad  diff_use_pred  year  month  \
# date
# 2013-08-06           0           0     0   0    0           -213  2013      8
# 2013-08-06           0           0     0   0    0           -261  2013      8
# 2013-08-06           0           0     0   0    0           -267  2013      8
# 2013-08-06           0           0     0   0    0             -1  2013      8
# 2013-08-06           0           0     0   0    0           -376  2013      8
#
#             day  wday
# date
# ...

# %%
# 1.
식당.pivot_table(index='date', aggfunc='sum', values='use_count').sort_values(by='use_count').tail()
# Out:
#             use_count
# date
# 2013-12-10       3568
# 2013-10-01       3569
# 2013-09-03       3581
# 2013-10-15       3627
# 2013-10-23       4267

# %%
# 2.
식당.pivot_table(index=['dine_type', 'corner'], aggfunc='count', values='use_count')
# Out:
#                          use_count
# dine_type corner
# breakfast rice & soup 1        476
#           take out             462
# dinner    after school         467
#           burger&pizza         451
#           grill & fry          459
#           noodle bar           456
#           rice & soup 1        474
#           take out             461
# lunch     after school         462
#           burger&pizza         462
#           grill & fry          466
#           noodle bar           467
#           rice & soup 1        472
#           rice & soup 2        332
#           take out             458

# %%
# 3. 
식당2014 = 식당.loc['2014']

# %% [markdown]
# ### 4. (실습 1) 전체 기간 동안, 아침, 점심, 저녁 메뉴로 가장 인기 있었던 메뉴를 각각 착기

# %%
식당.pivot_table(index=['dine_type', 'corner'], aggfunc='count', values='use_count')
# Out:
#                          use_count
# dine_type corner
# breakfast rice & soup 1        476
#           take out             462
# dinner    after school         467
#           burger&pizza         451
#           grill & fry          459
#           noodle bar           456
#           rice & soup 1        474
#           take out             461
# lunch     after school         462
#           burger&pizza         462
#           grill & fry          466
#           noodle bar           467
#           rice & soup 1        472
#           rice & soup 2        332
#           take out             458

# %% [markdown]
# ### 5. (실습 2) 2014년 한 해 동안, 각 코너 별  월별 판매량을 그래프로 시각화하기

# %%
# 3. 2014년 한 해 동안 가장 많은 판매량을 올린 메뉴 찾기
# 4. 2014년 한 해 동안 각 코너 별로 판매량을 그래프로 표현

# %%
import matplotlib.pyplot as plt
월별2014 = 식당['2014'].pivot_table(index=['corner', 'month'], aggfunc='sum', values='use_count')

# %%
월별2014 = 월별2014.unstack(0)

# %%
월별2014
# Out:
#           use_count                                                    \
# corner after school burger&pizza grill & fry noodle bar rice & soup 1
# month
# 1            6799.0       5549.0      8896.0     7985.0       19027.0
# 2            6731.0       5497.0      8591.0     7437.0       16191.0
# 3            7180.0       6447.0      9316.0     7622.0       12832.0
# 4            6826.0       6145.0      9218.0     7159.0       11837.0
# 5            5220.0       4505.0      8317.0     6614.0        9877.0
# 6            5389.0       4898.0      8684.0     6772.0       11046.0
# 7            6702.0       7228.0     11008.0     9254.0       13793.0
# 8            5161.0       6436.0      8740.0     7229.0       11623.0
# 9            4276.0       5855.0      7600.0     5751.0        9232.0
# 10           5014.0       6441.0      8261.0     6303.0       11550.0
# 11           4619.0       5707.0      8491.0     6040.0       10674.0
# ...

# %%
plt.style.use('ggplot')
월별2014.plot(figsize=(12,8), xticks=range(1,13))

# %% [markdown]
# ### 6. (실습 3) 매진을 가장 많이 기록한 상위 10개 메뉴와 매진횟수를 출력

# %%
식당.pivot_table(index='menu', value='is_sold_out', aggfunc='count').sort_values(by='is_sold')
